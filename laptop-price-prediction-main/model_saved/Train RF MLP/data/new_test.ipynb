# %%
import pandas as pd
data = pd.read_csv('1.csv')
# Define the condition for removing rows based on the 'Valid' column
condition = data['Valid'] > 0.01

# Apply the condition to filter the DataFrame
data = data[condition]
data.drop(columns=['Unnamed: 0','Unnamed: 14','Valid'], inplace=True)
data.to_csv('merge.csv', index=False)
data
# Out:
#      Brand                       CPU Name  CPU Mark  \
# 2277  Dell           Intel Core i7 13700H     28003
# 2278  ASUS           Intel Core i5 12500H     21525
# 2279  ASUS             AMD Ryzen 9 5900HX     22681
# 2280  Asus           Intel Core i9 13900H     29690
# 2281  Dell           Intel Core i7 12800H     24971
# ...    ...                            ...       ...
# 7976    HP  Intel Celeron N3060   1.60GHz       658
# 7977  Dell                      Intel N50      2350
# 7978  SGIN          Intel Celeron 2.93GHz       230
# 7979  Asus      Intel Atom N450   1.66GHz       203
# 7980  SGIN          Intel Celeron 2.50GHz       164
#
#                             GPU Name  GPU Mark  Monitor  Width  Height  RAM  \
# 2277                 Intel Arc A730M      8274     15.6   1920    1200   64
# 2278                   Intel Iris Xe      2690     15.6   1920    1080   16
# 2279  GeForce RTX 3050 Ti Laptop GPU     10181     15.6   1920    1080   16
# ...

# %%
import pandas as pd

# Read the CSV file
data = pd.read_csv('merge.csv')

# Randomly select 10% of the data
sample_data = data.sample(frac=0.1)

# Save the sampled data to a new CSV file
sample_data.to_csv('new_test.csv', index=False)
